# %% [markdown]
# <a href="https://colab.research.google.com/github/isys5002-itp/isys5002-2023-semester2/blob/main/05_2_using_paycalc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import paycalc module

# %%
import paycalc_module as pay
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
help(pay)
# Out:
# Help on module paycalc_module:
#
# NAME
#     paycalc_module - 05_2_paycalc_module.ipynb
#
# DESCRIPTION
#     Automatically generated by Colaboratory.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1FUxCoXJJ982JeSd08IGtA6_bNJfXpWlz
#
# FUNCTIONS
#     calculate_pay(salary, sales, comm)
#         This function calculates the commission, tax, and pay for a given salary, sales, and commission rate.
#
#         Inputs:
#         salary: an integer representing the user's salary
#         sales: an integer representing the user's sales
#         comm: a float representing the user's commission rate
#
#         Returns:
#         commission: a float representing the commission earned based on the sales and commission rate
#         tax: a float representing the tax amount calculated based on the salary and commission earned
#         pay: a float representing the pay after deducting tax from the salary and adding the commission earned
#
# ...

# %% [markdown]
# ## call the relevant functions from the `paycalc` module to
# * get user input
# * calculate the pay
# * print the payslip

# %%
# get user input
pay.user_input()
# Out:
# Please enter name: Rohini
# Please enter salary: 35000
# Please enter sales: 20000
# Please enter commission rate: 2
# ('Rohini', 35000, 20000, 2.0)

# %%
# unpacking the return values into variables
name, salary, sales, commission = pay.user_input()
# Out:
# Please enter name: Radha
# Please enter salary: 30000
# Please enter sales: 25000
# Please enter commission rate: 2

# %%
# test values in varibale
print(name)
print(salary)
# Out:
# Radha
# 30000

# %%
# calculate the pay

comm_result, tax_result, pay_result = pay.calculate_pay(salary, sales, commission)

# %%
# print the payslip

pay.print_payslip(name, salary, comm_result, tax_result, pay_result)
# Out:
# === Payslip of Radha ===
# Salary:     30000
# Commission: 500.0
# Tax:        2337.0
# Total pay:  28163.0

# %%
# Calalcuate staff pay and print payslip

# get user input
# unpacking the return values into variables
name, salary, sales, commission = pay.user_input()

# calculate the pay
comm_result, tax_result, pay_result = pay.calculate_pay(salary, sales, commission)

# print the payslip
pay.print_payslip(name, salary, comm_result, tax_result, pay_result)
# Out:
# Please enter name: Ram
# Please enter salary: 30000
# Please enter sales: 45000
# Please enter commission rate: 3
#
# === Payslip of Ram ===
# Salary:     30000
# Commission: 1350.0
# Tax:        2498.5
# Total pay:  28851.5
